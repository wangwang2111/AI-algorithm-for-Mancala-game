# %% [markdown]
# # Minimax on Mancala (State-Based)
#
# **Goal:** implement a correct, state-based **Minimax** for Mancala using the engine functions:
# - `legal_actions(state)`
# - `step(state, action)`
# - `evaluate(state)` (scores from the current player's perspective)
#
# We'll also handle Mancala’s **extra turn** rule properly and measure node counts.

# %% [markdown]
# ## 0) Setup
#
# If you have `core.py` in the same directory, it will be imported

# %%
# IF you have core.py in the same directory, it will be imported
from core import new_game, legal_actions, step, evaluate
# and you can use its functions here.
# ------------------------------------------------------------------------------

# quick sanity check (optional)
s = new_game(); print("Import OK. Example legal actions:", legal_actions(s))
# Out:
# Import OK. Example legal actions: [0, 1, 2, 3, 4, 5]

# %% [markdown]
# If you're running this from the repo root, the following cell makes sure Python can import from `src/`. Same with the Github REPO. Uncomment the following cell if needed.

# %%
# import os, sys, pathlib

# # --- Purpose ---------------------------------------------------------------
# # Make sure `src/` (project source root) is on PYTHONPATH so imports like
# # `from mancala_ai.engine.core import ...` work whether you run the script
# # from the repo root or a nested folder (e.g., tutorials/...).
# # ---------------------------------------------------------------------------

# # Resolve the absolute path to the current working directory, then go up two
# # levels to reach the repository root. Example structure:
# #   <repo-root>/
# #     src/
# #     tutorials/minimax_alpha/this_script.py
# # Path().resolve().parents[1] means "parent of parent" of CWD.
# REPO_ROOT = pathlib.Path().resolve().parents[1]

# # Build the path to the source folder (expected layout: <repo-root>/src)
# SRC = REPO_ROOT / "src"

# # Prepend `src` to sys.path only if it's not already there, to avoid duplicates.
# # This allows Python to locate `mancala_ai` package modules during import.
# if str(SRC) not in sys.path:
#     sys.path.insert(0, str(SRC))

# # Helpful sanity prints for debugging when running the script directly.
# print(REPO_ROOT, SRC)

# # After the path tweak, we can safely import from the project package.
# # These functions should live in: src/mancala_ai/engine/core.py
# from mancala_ai.engine.core import new_game, legal_actions, step, evaluate

# print("Imports OK. Repo root:", REPO_ROOT)

# # Tip:
# # If you only need this path manipulation for direct script runs (not when
# # imported as a module), you could wrap the sys.path logic in:
# #     if __name__ == "__main__":
# # but leaving it at top-level is fine for notebooks and quick scripts.
# Out:
# /mnt/c/Users/ndqua/OneDrive - Trent University/AMOD 5310H-AI/AI-algorithm-for-Mancala-game /mnt/c/Users/ndqua/OneDrive - Trent University/AMOD 5310H-AI/AI-algorithm-for-Mancala-game/src
# Imports OK. Repo root: /mnt/c/Users/ndqua/OneDrive - Trent University/AMOD 5310H-AI/AI-algorithm-for-Mancala-game

# %% [markdown]
# ## 1) Quick reminder: state shape
#
# ```python
# state = {
#   "pits": [[int]*6, [int]*6],   # row 0 = player_1, row 1 = player_2
#   "stores": [int, int],         # stores[0] = player_1 store, stores[1] = player_2 store
#   "current_player": 0 | 1       # 0 = player_1, 1 = player_2
# }
# ```

# %% [markdown]
# ## 2) Helpers: pretty print + fixed-perspective scoring
#
# We always score from the **root player's** perspective by temporarily setting `state["current_player"]` before calling `evaluate(state)`.

# %%
import copy
from typing import Dict
import random

def score_for(state, root_idx: int) -> float:
    """
    Evaluate the given game `state` from the perspective of `root_idx`.

    Notes:
    - We deep-copy the state so we don't mutate the caller's object.
    - We overwrite `current_player` to `root_idx` so that `evaluate(state)`
      scores the position for the root player consistently, regardless of
      whose turn it was in the incoming state.
    - Assumes an `evaluate(state)` function exists that returns a numeric score
      for the player indicated by `state['current_player']`.
    """
    s = copy.deepcopy(state)
    s["current_player"] = root_idx
    return float(evaluate(s))


def print_state(s):
    """
    Pretty-print a Mancala state.

    Expected state shape:
      s["pits"]   -> list-like of length 2, each with 6 pit counts (player 0 bottom, player 1 top)
      s["stores"] -> list-like of length 2, stores for players [P0, P1]
      s["current_player"] -> 0 or 1 (whose turn it is)

    The top row (P1) is reversed when printed to mimic a board view:
      P1  [pits reversed]   <-- top row (left-to-right as seen by P0)
      P0  [pits as-is]      <-- bottom row
    """
    p0, p1 = s["pits"][0], s["pits"][1]
    st0, st1 = s["stores"]
    turn = s["current_player"]

    print("+----- Mancala -----+")
    print("P1 store:", st1)
    print("P1 pits: ", list(reversed(p1)))  # reverse to display like a physical board
    print("P0 pits: ", p0)
    print("P0 store:", st0)
    print("Turn: P", turn, sep="")
    print("+-------------------+")

# %% [markdown]
# ## 3) Plain Minimax (no alpha-beta)
#
# **Key point:** If a move grants an **extra turn**, the ply did **not** change. So we **do not decrease depth** in that case.

# %%
import math
from typing import Dict, Optional, Tuple

class Stats:
    """Tiny container to track search statistics.

    Attributes
    ----------
    visits : int
        Number of nodes (states) expanded by the search.
    """
    def __init__(self):
        self.visits = 0


def minimax(state: Dict, depth: int, maximizing_player: int, stats: Stats) -> Tuple[float, Optional[int]]:
    """Plain Minimax (no alpha–beta) for Mancala using a state-based engine.

    Parameters
    ----------
    state : dict
        Current Mancala state:
        {
          "pits": [[int]*6, [int]*6],
          "stores": [int, int],
          "current_player": 0|1
        }
    depth : int
        Remaining search depth in plies (half-moves).
        NOTE: For Mancala, a move can grant an extra turn; when that happens
        we do NOT decrement depth (still the same ply).
    maximizing_player : int
        The index of the player we are maximizing for **at the root** (0 or 1).
        We score all leaf nodes from this fixed perspective.
    stats : Stats
        Mutable counter used to measure how many nodes we expand.

    Returns
    -------
    (value, best_move) : (float, Optional[int])
        - value: heuristic score from the root player's perspective.
        - best_move: pit index (0..5) for the CURRENT state's player,
          or None at leaves.

    Notes
    -----
    • This version does **not** perform alpha–beta pruning.
    • The evaluation function `score_for(...)` is assumed available in scope
      and must evaluate 'state' from the perspective of 'maximizing_player'.
    • The legal move generator `legal_actions(state)` and the state transition
      `step(state, action)` are also assumed available.
    """
    # Count this node expansion
    stats.visits += 1

    # --- Terminal / leaf check -----------------------------------------------
    # Stop if depth is exhausted OR either side has no stones in pits (terminal).
    if depth == 0 or sum(state["pits"][0]) == 0 or sum(state["pits"][1]) == 0:
        # Evaluate the position from the FIXED root player's perspective
        return score_for(state, maximizing_player), None

    # Generate legal actions for the current player (pit indices 0..5 that are non-empty)
    actions = legal_actions(state)
    if not actions:
        # No legal actions: treat as leaf and evaluate
        return score_for(state, maximizing_player), None

    # Decide whether this layer is maximizing or minimizing:
    # If it's the root player's turn, we maximize; otherwise minimize.
    is_max = (state["current_player"] == maximizing_player)

    # Initialize best move with something valid (used as fallback/tie-breaker).
    best_move = actions[0]

    if is_max:
        # ----------------------------- MAX layer ------------------------------
        best = -math.inf
        for a in actions:
            # Apply action -> next state, with (reward, done) ignored in tree search 
            # because reward here is simply difference in stores
            ns, _, _ = step(state, a)

            # Mancala "extra turn" rule:
            # If current_player stays the same after the move, it's still the same ply.
            # Do NOT decrement depth in that case.
            reduce = 0 if ns["current_player"] == state["current_player"] else 1

            v, _ = minimax(ns, depth - reduce, maximizing_player, stats)

            # Pick the move that maximizes the root player's score
            if v > best:
                best, best_move = v, a

        return best, best_move

    else:
        # ----------------------------- MIN layer ------------------------------
        best = math.inf
        for a in actions:
            ns, _, _ = step(state, a)
            reduce = 0 if ns["current_player"] == state["current_player"] else 1

            v, _ = minimax(ns, depth - reduce, maximizing_player, stats)

            # Pick the move that minimizes the root player's score
            if v < best:
                best, best_move = v, a

        return best, best_move


def choose_move_minimax(state: Dict, depth: int = 5) -> Tuple[int, Stats]:
    """Convenience wrapper: search and return a move for the current player.

    Parameters
    ----------
    state : dict
        Current Mancala state (see `minimax` docstring).
    depth : int, default=5
        Search depth in plies.

    Returns
    -------
    (move, stats) : (int, Stats)
        - move: selected pit index (0..5). If no legal moves exist, returns 0.
        - stats: node expansion statistics for this search.

    Notes
    -----
    • If something goes wrong and `minimax` returns None for the move (e.g.,
      at a leaf), we fall back to the first legal action to keep the game flowing.
    """
    stats = Stats()
    _, mv = minimax(state, depth, state["current_player"], stats)

    if mv is None:
        # Fallback safety: choose the first legal action if available
        acts = legal_actions(state)
        mv = int(acts[0]) if acts else 0

    return int(mv), stats

# %% [markdown]
# ## 4) Try it

# %%
s = new_game()
print_state(s)
mv, st = choose_move_minimax(s, depth=5)
print("Chosen move:", mv, "| nodes visited:", st.visits)
ns, _, _ = step(s, mv)
print_state(ns)
# Out:
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 4, 4, 4]
# P0 pits:  [4, 4, 4, 4, 4, 4]
# P0 store: 0
# Turn: P0
# +-------------------+
# Chosen move: 4 | nodes visited: 160971
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 4, 5, 5]
# P0 pits:  [4, 4, 4, 4, 0, 5]
# P0 store: 1
# Turn: P1
# +-------------------+

# %% [markdown]
# ## 5) Exercise — Full-game simulation
#
# Play Minimax vs Random to see it in action.

# %%
def random_move(state: Dict) -> int:
    """
    Pick and return a random legal move for the *current* player.

    Assumes:
      - `legal_actions(state)` returns a non-empty list of pit indices (or similar)
        that the current player is allowed to play.
      - If no actions exist (terminal state), returns 0 by convention.
    """
    acts = legal_actions(state)
    return random.choice(acts) if acts else 0


def play_game_minimax_vs_random(depth_minimax: int = 5, verbose: bool = False):
    """
    Play a full Mancala game: Player 0 uses minimax, Player 1 plays random.

    Parameters
    ----------
    depth_minimax : int
        Search depth for the minimax agent (Player 0).
    verbose : bool
        If True, print the state before each move and echo the chosen move.

    Assumptions
    -----------
    - `new_game()` returns an initial Mancala state with keys: pits, stores, current_player.
    - `choose_move_minimax(state, depth)` returns (best_move, best_value).
    - `step(state, move)` returns (next_state, reward, done_flag).
    - Terminal when sum of pits on either side is 0 (all stones on one side are empty).
    """
    s = new_game()

    # Loop until either side's pits are empty (end of game).
    while sum(s["pits"][0]) > 0 and sum(s["pits"][1]) > 0:

        if s["current_player"] == 0:
            # Player 0 (bottom) uses minimax
            mv, _ = choose_move_minimax(s, depth=depth_minimax)
            if verbose:
                print_state(s)
                # Note: At this point it's still Player 0's turn; we print the move about to be taken.
                print(f"Player {0} moved {mv}")
        else:
            # Player 1 (top) moves randomly
            mv = random_move(s)
            if verbose:
                print_state(s)
                # Similarly, printing the move about to be taken by Player 1.
                print(f"Player {1} moved {mv}")

        # Apply the move; step() handles captures, extra turns, store increments, and next-player logic.
        s, _, _ = step(s, mv)

    # Game is over; return the final state (stores now reflect final tally).
    return s


# --- Demo run (verbose) ---
final_state = play_game_minimax_vs_random(depth_minimax=5, verbose=True)
print_state(final_state)
# Out:
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 4, 4, 4]
# P0 pits:  [4, 4, 4, 4, 4, 4]
# P0 store: 0
# Turn: P0
# +-------------------+
# Player 0 moved 4
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 4, 5, 5]
# P0 pits:  [4, 4, 4, 4, 0, 5]
# P0 store: 1
# Turn: P1
# +-------------------+
# Player 1 moved 0
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [5, 5, 5, 5, 6, 0]
# P0 pits:  [4, 4, 4, 4, 0, 5]
# P0 store: 1
# Turn: P0
# +-------------------+
# Player 0 moved 0
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [5, 5, 5, 5, 0, 0]
# P0 pits:  [0, 5, 5, 5, 0, 5]
# P0 store: 8
# Turn: P1
# +-------------------+
# Player 1 moved 5
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 5, 5, 5, 0, 0]
# P0 pits:  [1, 6, 6, 6, 0, 5]
# P0 store: 8
# Turn: P0
# +-------------------+
# Player 0 moved 0
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 5, 5, 5, 0, 0]
# P0 pits:  [0, 7, 6, 6, 0, 5]
# P0 store: 8
# Turn: P1
# +-------------------+
# Player 1 moved 4
# +----- Mancala -----+
# P1 store: 2
# P1 pits:  [1, 0, 5, 5, 0, 0]
# P0 pits:  [1, 8, 7, 6, 0, 5]
# P0 store: 8
# Turn: P0
# +-------------------+
# Player 0 moved 3
# +----- Mancala -----+
# P1 store: 2
# P1 pits:  [1, 0, 5, 6, 1, 1]
# P0 pits:  [1, 8, 7, 0, 1, 6]
# P0 store: 9
# Turn: P1
# +-------------------+
# Player 1 moved 0
# +----- Mancala -----+
# P1 store: 2
# P1 pits:  [1, 0, 5, 6, 2, 0]
# P0 pits:  [1, 8, 7, 0, 1, 6]
# P0 store: 9
# Turn: P0
# +-------------------+
# Player 0 moved 1
# +----- Mancala -----+
# P1 store: 2
# P1 pits:  [1, 0, 5, 7, 3, 1]
# P0 pits:  [1, 0, 8, 1, 2, 7]
# P0 store: 10
# Turn: P1
# +-------------------+
# Player 1 moved 2
# +----- Mancala -----+
# P1 store: 3
# P1 pits:  [2, 1, 6, 0, 3, 1]
# P0 pits:  [2, 1, 9, 1, 2, 7]
# P0 store: 10
# Turn: P0
# +-------------------+
# Player 0 moved 4
# +----- Mancala -----+
# P1 store: 3
# P1 pits:  [2, 1, 6, 0, 3, 1]
# P0 pits:  [2, 1, 9, 1, 0, 8]
# P0 store: 11
# Turn: P0
# +-------------------+
# Player 0 moved 2
# +----- Mancala -----+
# P1 store: 3
# P1 pits:  [2, 2, 7, 1, 4, 2]
# P0 pits:  [2, 1, 0, 2, 1, 9]
# P0 store: 12
# Turn: P1
# +-------------------+
# Player 1 moved 0
# +----- Mancala -----+
# P1 store: 3
# P1 pits:  [2, 2, 7, 2, 5, 0]
# P0 pits:  [2, 1, 0, 2, 1, 9]
# P0 store: 12
# Turn: P0
# +-------------------+
# Player 0 moved 1
# +----- Mancala -----+
# P1 store: 3
# P1 pits:  [2, 2, 0, 2, 5, 0]
# P0 pits:  [2, 0, 0, 2, 1, 9]
# P0 store: 20
# Turn: P1
# +-------------------+
# Player 1 moved 1
# +----- Mancala -----+
# P1 store: 4
# P1 pits:  [3, 3, 1, 3, 0, 0]
# P0 pits:  [2, 0, 0, 2, 1, 9]
# P0 store: 20
# Turn: P1
# +-------------------+
# Player 1 moved 5
# +----- Mancala -----+
# P1 store: 5
# P1 pits:  [0, 3, 1, 3, 0, 0]
# P0 pits:  [3, 1, 0, 2, 1, 9]
# P0 store: 20
# Turn: P0
# +-------------------+
# Player 0 moved 1
# +----- Mancala -----+
# P1 store: 5
# P1 pits:  [0, 3, 0, 3, 0, 0]
# P0 pits:  [3, 0, 0, 2, 1, 9]
# P0 store: 22
# Turn: P1
# +-------------------+
# Player 1 moved 4
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [1, 0, 0, 3, 0, 0]
# P0 pits:  [4, 0, 0, 2, 1, 9]
# P0 store: 22
# Turn: P0
# +-------------------+
# Player 0 moved 0
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [1, 0, 0, 3, 0, 0]
# P0 pits:  [0, 1, 1, 3, 2, 9]
# P0 store: 22
# Turn: P1
# +-------------------+
# Player 1 moved 2
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [2, 1, 1, 0, 0, 0]
# P0 pits:  [0, 1, 1, 3, 2, 9]
# P0 store: 22
# Turn: P0
# +-------------------+
# Player 0 moved 1
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [2, 1, 1, 0, 0, 0]
# P0 pits:  [0, 0, 2, 3, 2, 9]
# P0 store: 22
# Turn: P1
# +-------------------+
# Player 1 moved 4
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [3, 0, 1, 0, 0, 0]
# P0 pits:  [0, 0, 2, 3, 2, 9]
# P0 store: 22
# Turn: P0
# +-------------------+
# Player 0 moved 5
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [4, 0, 2, 1, 1, 1]
# P0 pits:  [1, 0, 2, 3, 2, 0]
# P0 store: 25
# Turn: P1
# +-------------------+
# Player 1 moved 0
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [4, 0, 2, 1, 2, 0]
# P0 pits:  [1, 0, 2, 3, 2, 0]
# P0 store: 25
# Turn: P0
# +-------------------+
# Player 0 moved 4
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [4, 0, 2, 1, 2, 0]
# P0 pits:  [1, 0, 2, 3, 0, 1]
# P0 store: 26
# Turn: P0
# +-------------------+
# Player 0 moved 2
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [4, 0, 2, 1, 0, 0]
# P0 pits:  [1, 0, 0, 4, 0, 1]
# P0 store: 29
# Turn: P1
# +-------------------+
# Player 1 moved 2
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [4, 0, 3, 0, 0, 0]
# P0 pits:  [1, 0, 0, 4, 0, 1]
# P0 store: 29
# Turn: P0
# +-------------------+
# Player 0 moved 0
# +----- Mancala -----+
# P1 store: 6
# P1 pits:  [4, 0, 3, 0, 0, 0]
# P0 pits:  [0, 1, 0, 4, 0, 1]
# P0 store: 29
# Turn: P1
# +-------------------+
# Player 1 moved 3
# +----- Mancala -----+
# P1 store: 7
# P1 pits:  [5, 1, 0, 0, 0, 0]
# P0 pits:  [0, 1, 0, 4, 0, 1]
# P0 store: 29
# Turn: P1
# +-------------------+
# Player 1 moved 4
# +----- Mancala -----+
# P1 store: 7
# P1 pits:  [6, 0, 0, 0, 0, 0]
# P0 pits:  [0, 1, 0, 4, 0, 1]
# P0 store: 29
# Turn: P0
# +-------------------+
# Player 0 moved 3
# +----- Mancala -----+
# P1 store: 7
# P1 pits:  [6, 0, 0, 0, 0, 1]
# P0 pits:  [0, 1, 0, 0, 1, 2]
# P0 store: 30
# Turn: P1
# +-------------------+
# Player 1 moved 5
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 0, 0, 1]
# P0 pits:  [1, 2, 1, 1, 2, 2]
# P0 store: 30
# Turn: P0
# +-------------------+
# Player 0 moved 4
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 0, 0, 1]
# P0 pits:  [1, 2, 1, 1, 0, 3]
# P0 store: 31
# Turn: P0
# +-------------------+
# Player 0 moved 1
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 0, 0, 1]
# P0 pits:  [1, 0, 2, 2, 0, 3]
# P0 store: 31
# Turn: P1
# +-------------------+
# Player 1 moved 0
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 0, 1, 0]
# P0 pits:  [1, 0, 2, 2, 0, 3]
# P0 store: 31
# Turn: P0
# +-------------------+
# Player 0 moved 3
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 0, 1, 0]
# P0 pits:  [1, 0, 2, 0, 1, 4]
# P0 store: 31
# Turn: P1
# +-------------------+
# Player 1 moved 1
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 1, 0, 0]
# P0 pits:  [1, 0, 2, 0, 1, 4]
# P0 store: 31
# Turn: P0
# +-------------------+
# Player 0 moved 2
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 0, 1, 0, 0]
# P0 pits:  [1, 0, 0, 1, 2, 4]
# P0 store: 31
# Turn: P1
# +-------------------+
# Player 1 moved 2
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 1, 0, 0, 0]
# P0 pits:  [1, 0, 0, 1, 2, 4]
# P0 store: 31
# Turn: P0
# +-------------------+
# Player 0 moved 5
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 1, 1, 1, 1]
# P0 pits:  [1, 0, 0, 1, 2, 0]
# P0 store: 32
# Turn: P1
# +-------------------+
# Player 1 moved 1
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 1, 2, 0, 1]
# P0 pits:  [1, 0, 0, 1, 2, 0]
# P0 store: 32
# Turn: P0
# +-------------------+
# Player 0 moved 0
# +----- Mancala -----+
# P1 store: 8
# P1 pits:  [0, 0, 1, 2, 0, 1]
# P0 pits:  [0, 1, 0, 1, 2, 0]
# P0 store: 32
# Turn: P1
# +-------------------+
# Player 1 moved 3
# +----- Mancala -----+
# P1 store: 10
# P1 pits:  [0, 0, 0, 2, 0, 1]
# P0 pits:  [0, 0, 0, 1, 2, 0]
# P0 store: 32
# Turn: P0
# +-------------------+
# Player 0 moved 4
# +----- Mancala -----+
# P1 store: 10
# P1 pits:  [0, 0, 0, 2, 0, 1]
# P0 pits:  [0, 0, 0, 1, 0, 1]
# P0 store: 33
# Turn: P0
# +-------------------+
# Player 0 moved 3
# +----- Mancala -----+
# P1 store: 10
# P1 pits:  [0, 0, 0, 2, 0, 1]
# P0 pits:  [0, 0, 0, 0, 1, 1]
# P0 store: 33
# Turn: P1
# +-------------------+
# Player 1 moved 2
# +----- Mancala -----+
# P1 store: 10
# P1 pits:  [0, 1, 1, 0, 0, 1]
# P0 pits:  [0, 0, 0, 0, 1, 1]
# P0 store: 33
# Turn: P0
# +-------------------+
# Player 0 moved 5
# +----- Mancala -----+
# P1 store: 10
# P1 pits:  [0, 1, 1, 0, 0, 1]
# P0 pits:  [0, 0, 0, 0, 1, 0]
# P0 store: 34
# Turn: P0
# +-------------------+
# Player 0 moved 4
# +----- Mancala -----+
# P1 store: 12
# P1 pits:  [0, 0, 0, 0, 0, 0]
# P0 pits:  [0, 0, 0, 0, 0, 0]
# P0 store: 36
# Turn: P1
# +-------------------+
