# %% [markdown]
# # Alpha–Beta Pruning on Mancala (State-Based)
#
# We’ll upgrade Minimax with **Alpha–Beta pruning** and show how **move ordering** reduces the number of expanded nodes. We continue to use the state-based engine:
# - `legal_actions(state)`
# - `step(state, action)`
# - `evaluate(state)`

# %% [markdown]
# ## 0) Setup

# %%
# IF you have core.py in the same directory, it will be imported
from core import new_game, legal_actions, step, evaluate
# and you can use its functions here.
# ------------------------------------------------------------------------------

# quick sanity check (optional)
s = new_game(); print("Import OK. Example legal actions:", legal_actions(s))
# Out:
# Import OK. Example legal actions: [0, 1, 2, 3, 4, 5]

# %% [markdown]
# If you're running this from the repo root, the following cell makes sure Python can import from `src/`. Same with the Github REPO.

# %%
# import os, sys, pathlib
# REPO_ROOT = pathlib.Path().resolve().parents[1]  # .../tutorials/minimax_alpha/ -> repo root
# SRC = REPO_ROOT / "src"
# if str(SRC) not in sys.path:
#     sys.path.insert(0, str(SRC))

# from mancala_ai.engine.core import new_game, legal_actions, step, evaluate
# print("Imports OK. Repo root:", REPO_ROOT)

# %% [markdown]
# ## 1) Helpers

# %%
import copy
from typing import Dict
import random

def score_for(state, root_idx: int) -> float:
    """
    Evaluate the given game `state` from the perspective of `root_idx`.

    Notes:
    - We deep-copy the state so we don't mutate the caller's object.
    - We overwrite `current_player` to `root_idx` so that `evaluate(state)`
      scores the position for the root player consistently, regardless of
      whose turn it was in the incoming state.
    - Assumes an `evaluate(state)` function exists that returns a numeric score
      for the player indicated by `state['current_player']`.
    """
    s = copy.deepcopy(state)
    s["current_player"] = root_idx
    return float(evaluate(s))


def print_state(s):
    """
    Pretty-print a Mancala state.

    Expected state shape:
      s["pits"]   -> list-like of length 2, each with 6 pit counts (player 0 bottom, player 1 top)
      s["stores"] -> list-like of length 2, stores for players [P0, P1]
      s["current_player"] -> 0 or 1 (whose turn it is)

    The top row (P1) is reversed when printed to mimic a board view:
      P1  [pits reversed]   <-- top row (left-to-right as seen by P0)
      P0  [pits as-is]      <-- bottom row
    """
    p0, p1 = s["pits"][0], s["pits"][1]
    st0, st1 = s["stores"]
    turn = s["current_player"]

    print("+----- Mancala -----+")
    print("P1 store:", st1)
    print("P1 pits: ", list(reversed(p1)))  # reverse to display like a physical board
    print("P0 pits: ", p0)
    print("P0 store:", st0)
    print("Turn: P", turn, sep="")
    print("+-------------------+")
    
class Stats:
    """Tiny container to track search statistics.

    Attributes
    ----------
    visits : int
        Number of nodes (states) expanded by the search.
    """
    def __init__(self):
        self.visits = 0

# %% [markdown]
# ## 2) Simple one-ply ordering (optional but recommended)
#
# We order actions by the one-ply score of the resulting state (from the root player’s perspective).

# %%
from typing import List, Dict
import math

# NOTE: `Stats` is assumed to be a simple container with at least `visits: int`.
# e.g., @dataclass class Stats: visits:int=0
# If your class has different fields, keep `stats.visits += 1` as-is.


def order_moves_simple(state: Dict, root_idx: int) -> List[int]:
    """
    Naive move ordering by one-ply static evaluation.

    For each legal action:
      - Apply it to get the next state (ns).
      - Score ns from the perspective of `root_idx` via `score_for`.
    Then sort moves by that score descending and return the move list.

    This is a cheap heuristic that often improves alpha-beta pruning by
    presenting likely-better moves first.
    """
    acts = legal_actions(state)
    scored = []
    for a in acts:
        ns, _, _ = step(state, a)                    # simulate move a
        scored.append((score_for(ns, root_idx), a))  # (score, move)
    scored.sort(reverse=True)                        # highest score first
    return [a for _, a in scored]                    # return only moves

# %% [markdown]
# ## 3) Alpha–Beta with correct extra-turn handling

# %%
def alphabeta(
    state: Dict,
    depth: int,
    alpha: float,
    beta: float,
    root_idx: int,
    stats: "Stats",
    use_ordering: bool = True
):
    """
    Alpha-beta search with optional move ordering and Mancala extra-turn handling.

    Parameters
    ----------
    state : dict
        Current Mancala state. Must include:
          - "pits": [p0_pits[0..5], p1_pits[0..5]]
          - "stores": [p0_store, p1_store]
          - "current_player": 0 or 1
    depth : int
        Remaining search depth in plies. Depth may *not* decrease on child calls
        if the move grants an extra turn (see `reduce` logic).
    alpha, beta : float
        Standard alpha-beta bounds.
    root_idx : int
        Player index (0/1) for whom we are evaluating the position (root perspective).
    stats : Stats
        Mutable stats accumulator (e.g., counts expanded nodes).
    use_ordering : bool
        If True, order moves by a one-ply static evaluation before searching.

    Returns
    -------
    (value, best_move) : (float, int|None)
        value: minimax value from the perspective of `root_idx`.
        best_move: chosen move at this node (None for leaves).

    Notes
    -----
    • Terminal/leaf conditions:
        - depth == 0
        - One side has no stones left in pits (end game)
        - No legal actions
      In these cases we return a static evaluation.
    • Extra turns (Mancala rule):
        If the resulting state's `current_player` is the same as before,
        we do *not* reduce depth for that child (search continues at same ply).
    """
    stats.visits += 1

    # Leaf or terminal: evaluate directly from root player's perspective.
    if depth == 0 or sum(state["pits"][0]) == 0 or sum(state["pits"][1]) == 0:
        return score_for(state, root_idx), None

    acts = legal_actions(state)
    if not acts:
        return score_for(state, root_idx), None

    # Maximizing if it's the root player's turn; minimizing otherwise.
    is_max = (state["current_player"] == root_idx)

    # Optionally pre-order moves to improve pruning efficiency.
    ordered = order_moves_simple(state, root_idx) if use_ordering else acts
    best_move = ordered[0]  # default to first candidate (useful if all equal)

    if is_max:
        val = -math.inf
        a = alpha
        for mv in ordered:
            ns, _, _ = step(state, mv)

            # Depth reduction: if we keep the turn (extra turn), do NOT reduce depth.
            reduce = 0 if ns["current_player"] == state["current_player"] else 1

            child_v, _ = alphabeta(ns, depth - reduce, a, beta, root_idx, stats, use_ordering)

            # Standard maximizing update
            if child_v > val:
                val, best_move = child_v, mv

            # Update alpha and prune if possible
            a = max(a, val)
            if beta <= a:  # beta cut
                break

        return val, best_move

    else:
        val = math.inf
        b = beta
        for mv in ordered:
            ns, _, _ = step(state, mv)

            # Same extra-turn handling for minimizing branch
            reduce = 0 if ns["current_player"] == state["current_player"] else 1

            child_v, _ = alphabeta(ns, depth - reduce, alpha, b, root_idx, stats, use_ordering)

            # Standard minimizing update
            if child_v < val:
                val, best_move = child_v, mv

            # Update beta and prune if possible
            b = min(b, val)
            if b <= alpha:  # alpha cut
                break

        return val, best_move


def choose_move_alphabeta(state: Dict, depth: int = 7, use_ordering: bool = True):
    """
    Convenience wrapper: pick a move for the *current player* using alpha-beta.

    Parameters
    ----------
    state : dict
        Current Mancala state (see `alphabeta` docstring for required keys).
    depth : int, default=7
        Search depth in plies (a "ply" is one player's move).
    use_ordering : bool, default=True
        Enable one-ply move ordering to improve pruning.

    Returns
    -------
    (move, stats) : (int, Stats)
        move : chosen pit index for the current player (0..5).
                If no legal moves exist or search returns None, falls back to
                the first legal move or 0 if none exist (keeps the game moving).
        stats: node-expansion statistics for this search (e.g., visits count).

    Notes
    -----
    • Uses wide initial bounds (-1e9, 1e9) to avoid importing math.inf at call site.
    • In rare leaf cases, `alphabeta` can return (value, None); we handle that
      by picking the first legal action as a safe fallback.
    """
    stats = Stats()
    _, mv = alphabeta(
        state,
        depth,
        -1e9,
        1e9,
        state["current_player"],
        stats,
        use_ordering=use_ordering
    )

    # Fallback: ensure we always return a legal move if possible.
    if mv is None:
        acts = legal_actions(state)
        mv = int(acts[0]) if acts else 0

    return int(mv), stats

# %% [markdown]
# ## 4) Experiments
#
# Compare node counts for Minimax vs Alpha–Beta, and Alpha–Beta with vs without ordering.

# %%
import random
from typing import Dict, Tuple
import math               # for +/- infinity in _minimax

# --- Baseline position ------------------------------------------------------
# Start from the standard initial Mancala state.
s = new_game()

# We'll advance a few plies letting:
# - Player 0: alpha-beta (depth 5, with move ordering)
# - Player 1: random move
ns = s
for _ in range(5):
    if s["current_player"] == 0:
        # Choose a move for Player 0 using alpha-beta + ordering
        mv_ab, _ = choose_move_alphabeta(ns, depth=5, use_ordering=True)
        ns, _, _ = step(ns, mv_ab)  # apply the move
    else:
        # Player 1 plays randomly from legal actions
        mv_random = random.choice(legal_actions(ns))
        ns, _, _ = step(ns, mv_random)
    # Show the board after each move to track progression
    print_state(ns)


# --- Plain minimax for comparison -------------------------------------------
# Lightweight stats holder (only node visit count needed here).
class _MStats: 
    def __init__(self):
        self.visits = 0

def _minimax(state: Dict, depth: int, root_idx: int, st: _MStats):
    """
    Simple minimax without alpha-beta pruning, but with Mancala extra-turn handling.
    - depth: search depth in plies
    - root_idx: evaluate from this player's perspective (0 or 1)
    - st: counts nodes visited
    """
    st.visits += 1

    # Leaf/terminal: reached depth limit or one side has no stones in pits.
    if depth == 0 or sum(state["pits"][0]) == 0 or sum(state["pits"][1]) == 0:
        return score_for(state, root_idx), None

    acts = legal_actions(state)
    if not acts:
        return score_for(state, root_idx), None

    # Maximize if it's root player's turn; otherwise minimize.
    is_max = (state["current_player"] == root_idx)
    best_mv = acts[0]  # default to first move for tie/initialization

    if is_max:
        val = -math.inf
        for mv in acts:
            ns, _, _ = step(state, mv)
            # Extra-turn rule: if child keeps the same player to move, don't reduce depth
            reduce = 0 if ns["current_player"] == state["current_player"] else 1
            v, _ = _minimax(ns, depth - reduce, root_idx, st)
            if v > val:
                val, best_mv = v, mv
        return val, best_mv
    else:
        val = math.inf
        for mv in acts:
            ns, _, _ = step(state, mv)
            reduce = 0 if ns["current_player"] == state["current_player"] else 1
            v, _ = _minimax(ns, depth - reduce, root_idx, st)
            if v < val:
                val, best_mv = v, mv
        return val, best_mv


def choose_move_minimax(state: Dict, depth: int = 5) -> Tuple[int, Stats]:
    """Convenience wrapper: search and return a move for the current player.

    Parameters
    ----------
    state : dict
        Current Mancala state (see `minimax` docstring).
    depth : int, default=5
        Search depth in plies.

    Returns
    -------
    (move, stats) : (int, Stats)
        - move: selected pit index (0..5). If no legal moves exist, returns 0.
        - stats: node expansion statistics for this search.

    Notes
    -----
    • If something goes wrong and `minimax` returns None for the move (e.g.,
      at a leaf), we fall back to the first legal action to keep the game flowing.
    """
    stats = Stats()
    _, mv = _minimax(state, depth, state["current_player"], stats)

    if mv is None:
        # Fallback safety: choose the first legal action if available
        acts = legal_actions(state)
        mv = int(acts[0]) if acts else 0

    return int(mv), stats


# Run minimax once from the current node to compare node counts/choice.
mv_min, st_min = choose_move_minimax(ns, depth=5)
print("Minimax   -> nodes:", st_min.visits, "move:", mv_min)

# Alpha-beta w/o move ordering: expect fewer nodes than plain minimax, but more than ordered.
mv_ab_no, st_ab_no = choose_move_alphabeta(ns, depth=5, use_ordering=False)
print("AlphaBeta (no order) -> nodes:", st_ab_no.visits, "move:", mv_ab_no)

# Alpha-beta with simple one-ply ordering: usually the smallest node count.
mv_ab, st_ab = choose_move_alphabeta(ns, depth=5, use_ordering=True)
print("AlphaBeta (ordered)  -> nodes:", st_ab.visits, "move:", mv_ab)
# Out:
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 5, 5, 5]
# P0 pits:  [4, 4, 4, 4, 4, 0]
# P0 store: 1
# Turn: P1
# +-------------------+
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 5]
# P0 pits:  [5, 5, 5, 4, 4, 0]
# P0 store: 1
# Turn: P0
# +-------------------+
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 5]
# P0 pits:  [5, 0, 6, 5, 5, 1]
# P0 store: 2
# Turn: P0
# +-------------------+
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 5]
# P0 pits:  [5, 0, 6, 5, 5, 0]
# P0 store: 3
# Turn: P0
# +-------------------+
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 0]
# P0 pits:  [0, 1, 7, 6, 6, 0]
# P0 store: 9
# Turn: P1
# +-------------------+
# Minimax   -> nodes: 19183 move: 1
# AlphaBeta (no order) -> nodes: 4908 move: 1
# AlphaBeta (ordered)  -> nodes: 2271 move: 1

# %% [markdown]
# ## 5) Run Full Game Simulation

# %%
from typing import Dict, Callable, Tuple, Optional

def random_move(state: Dict) -> int:
    """
    Pick and return a random legal move for the *current* player.

    Assumes:
      - `legal_actions(state)` returns a non-empty list of pit indices (or similar)
        that the current player is allowed to play.
      - If no actions exist (terminal state), returns 0 by convention.
    """
    acts = legal_actions(state)
    return random.choice(acts) if acts else 0


def _make_chooser(engine_name: str,
                  depth_minimax: int,
                  depth_ab: int) -> Callable[[Dict], Tuple[int, Optional["Stats"]]]:
    """
    Build a (state) -> (move, stats_or_None) chooser from an engine name.

    Accepted names (case-insensitive, aliases included):
      - "random"
      - "minimax"
      - "alphabeta", "alpha-beta", "ab"
      - "alphabeta_ordered", "alpha-beta-ordered", "ab_ordered", "alpha-beta+ordering"
    """
    name = (engine_name or "").strip().lower()

    if name == "random":
        def chooser(state: Dict):
            return random_move(state), None
        return chooser

    if name == "minimax":
        def chooser(state: Dict):
            mv, stats = choose_move_minimax(state, depth=depth_minimax)
            return mv, stats
        return chooser

    if name in {"alphabeta", "alpha-beta", "ab"}:
        def chooser(state: Dict):
            mv, stats = choose_move_alphabeta(state, depth=depth_ab, use_ordering=False)
            return mv, stats
        return chooser

    if name in {"alphabeta_ordered", "alpha-beta-ordered", "ab_ordered", "alpha-beta+ordering", "alpha-beta with ordering"}:
        def chooser(state: Dict):
            mv, stats = choose_move_alphabeta(state, depth=depth_ab, use_ordering=True)
            return mv, stats
        return chooser

    raise ValueError(f"Unknown engine '{engine_name}'. "
                     f"Use one of: random, minimax, alphabeta, alphabeta_ordered.")


def play_game(engine_p0: str = "minimax",
              engine_p1: str = "random",
              depth_minimax: int = 5,
              depth_ab: int = 5,
              verbose: bool = False) -> Dict:
    """
    Play a full Mancala game with configurable engines per player.

    Parameters
    ----------
    engine_p0 : str, default="minimax"
        Engine for Player 0. One of:
          "random", "minimax", "alphabeta", "alphabeta_ordered"
    engine_p1 : str, default="random"
        Engine for Player 1. Same options as engine_p0.
    depth_minimax : int, default=5
        Search depth used when the selected engine is "minimax".
    depth_ab : int, default=5
        Search depth used when the selected engine is "alphabeta" or "alphabeta_ordered".
    verbose : bool, default=False
        If True, print the state before each move and echo the move chosen.

    Returns
    -------
    final_state : dict
        Terminal Mancala state after the game finishes.
    """
    # Build chooser functions for each side
    choose0 = _make_chooser(engine_p0, depth_minimax=depth_minimax, depth_ab=depth_ab)
    choose1 = _make_chooser(engine_p1, depth_minimax=depth_minimax, depth_ab=depth_ab)

    s = new_game()

    # Loop until either side's pits are empty (end of game)
    while sum(s["pits"][0]) > 0 and sum(s["pits"][1]) > 0:
        if verbose:
            print_state(s)

        # If no legal actions for the side to move, game ends safely
        acts = legal_actions(s)
        if not acts:
            break

        if s["current_player"] == 0:
            mv, _ = choose0(s)
            # Safety: if an engine returns an illegal move, fall back to first legal
            if mv not in acts:
                mv = acts[0]
            if verbose:
                print(f"P0 ({engine_p0}) moved {mv}")
        else:
            mv, _ = choose1(s)
            if mv not in acts:
                mv = acts[0]
            if verbose:
                print(f"P1 ({engine_p1}) moved {mv}")

        # Apply the move; handles captures, extra turn, and next-player logic
        s, _, _ = step(s, mv)

    if verbose:
        print("=== Final State ===")
        print_state(s)

    return s


# --- Examples ---
final_state = play_game(engine_p0="alphabeta_ordered", engine_p1="minimax", depth_ab=4, verbose=True)
# final_state = play_game(engine_p0="minimax", engine_p1="alphabeta", depth_minimax=5, depth_ab=4, verbose=False)
# Out:
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 4, 4, 4]
# P0 pits:  [4, 4, 4, 4, 4, 4]
# P0 store: 0
# Turn: P0
# +-------------------+
# P0 (alphabeta_ordered) moved 5
# +----- Mancala -----+
# P1 store: 0
# P1 pits:  [4, 4, 4, 5, 5, 5]
# P0 pits:  [4, 4, 4, 4, 4, 0]
# P0 store: 1
# Turn: P1
# +-------------------+
# P1 (minimax) moved 5
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 5]
# P0 pits:  [5, 5, 5, 4, 4, 0]
# P0 store: 1
# Turn: P0
# +-------------------+
# P0 (alphabeta_ordered) moved 1
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 5]
# P0 pits:  [5, 0, 6, 5, 5, 1]
# P0 store: 2
# Turn: P0
# +-------------------+
# P0 (alphabeta_ordered) moved 5
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 5]
# P0 pits:  [5, 0, 6, 5, 5, 0]
# P0 store: 3
# Turn: P0
# +-------------------+
# P0 (alphabeta_ordered) moved 0
# +----- Mancala -----+
# P1 store: 1
# P1 pits:  [0, 4, 4, 5, 5, 0]
# P0 pits:  [0, 1, 7, 6, 6, 0]
# ...

# %% [markdown]
# # 6) Simulate Multiple Games and Summarize Results

# %%
import time

# --- Helpers to measure a single move ---------------------------------------

def _measure_move(state: Dict,
                  chooser: Callable[[Dict], Tuple[int, Optional["Stats"]]]) -> Tuple[int, int, float]:
    """
    Run one move selection with timing and node counting.
    Returns:
        (move, visits, elapsed_sec)
    """
    t0 = time.time()
    mv, st = chooser(state)
    dt = time.time() - t0
    visits = getattr(st, "visits", 0) if st is not None else 0
    return mv, int(visits), float(dt)


def play_game_with_stats(engine_p0: str = "minimax",
                         engine_p1: str = "random",
                         depth_minimax: int = 5,
                         depth_ab: int = 5,
                         verbose: bool = False) -> Tuple[Dict, int, Dict]:
    """
    Play a full game and collect per-side totals:
      - total moves
      - total nodes (visits)
      - total time (seconds)

    Returns:
      final_state, winner (0/1 or -1 for tie), stats dict:
        {
          'P0': {'moves': int, 'nodes': int, 'time': float},
          'P1': {'moves': int, 'nodes': int, 'time': float},
        }
    """
    choose0 = _make_chooser(engine_p0, depth_minimax=depth_minimax, depth_ab=depth_ab)
    choose1 = _make_chooser(engine_p1, depth_minimax=depth_minimax, depth_ab=depth_ab)

    s = new_game()
    stats = {'P0': {'moves': 0, 'nodes': 0, 'time': 0.0},
             'P1': {'moves': 0, 'nodes': 0, 'time': 0.0}}

    while sum(s["pits"][0]) > 0 and sum(s["pits"][1]) > 0:
        if verbose:
            print_state(s)

        acts = legal_actions(s)
        if not acts:
            break

        if s["current_player"] == 0:
            mv, visits, dt = _measure_move(s, choose0)
            if mv not in acts:
                mv = acts[0]
            if verbose:
                print(f"P0 ({engine_p0}) -> move {mv}  | visits={visits}  time={dt:.4f}s")
            stats['P0']['moves'] += 1
            stats['P0']['nodes'] += visits
            stats['P0']['time']  += dt
        else:
            mv, visits, dt = _measure_move(s, choose1)
            if mv not in acts:
                mv = acts[0]
            if verbose:
                print(f"P1 ({engine_p1}) -> move {mv}  | visits={visits}  time={dt:.4f}s")
            stats['P1']['moves'] += 1
            stats['P1']['nodes'] += visits
            stats['P1']['time']  += dt

        s, _, _ = step(s, mv)

    # Decide winner by stores (assumes terminal tally done by engine)
    st0, st1 = s["stores"]
    winner = 0 if st0 > st1 else (1 if st1 > st0 else -1)

    if verbose:
        print("=== Final State ===")
        print_state(s)
        print(f"Winner: {'P0' if winner==0 else ('P1' if winner==1 else 'Tie')} (P0 store={st0}, P1 store={st1})")

    return s, winner, stats


# --- Simulation over many games ---------------------------------------------

def simulate_games(n_games: int = 20,
                   engine_p0: str = "alphabeta_ordered",
                   engine_p1: str = "random",
                   depth_minimax: int = 5,
                   depth_ab: int = 5,
                   seed: Optional[int] = None,
                   verbose_every: int = 0):
    """
    Play n_games with fixed engines and report:
      - P0 win rate
      - Avg nodes per move (P0, P1)
      - Avg time per move (P0, P1)

    If `seed` is provided, randomness (for random engine) is reproducible.
    If `verbose_every` > 0, prints a short line every k games.
    """
    if seed is not None:
        random.seed(seed)

    wins_p0 = 0
    ties = 0

    agg = {'P0': {'moves': 0, 'nodes': 0, 'time': 0.0},
           'P1': {'moves': 0, 'nodes': 0, 'time': 0.0}}

    for g in range(1, n_games + 1):
        _, winner, st = play_game_with_stats(
            engine_p0=engine_p0,
            engine_p1=engine_p1,
            depth_minimax=depth_minimax,
            depth_ab=depth_ab,
            verbose=False
        )
        if winner == 0:
            wins_p0 += 1
        elif winner == -1:
            ties += 1

        # accumulate totals
        for side in ('P0', 'P1'):
            agg[side]['moves'] += st[side]['moves']
            agg[side]['nodes'] += st[side]['nodes']
            agg[side]['time']  += st[side]['time']

        if verbose_every and (g % verbose_every == 0):
            print(f"[{g}/{n_games}] interim: P0 wins={wins_p0}, ties={ties}")

    # Compute averages (guard against divide-by-zero)
    def _avg_nodes(side):
        return (agg[side]['nodes'] / agg[side]['moves']) if agg[side]['moves'] else 0.0

    def _avg_time(side):
        return (agg[side]['time'] / agg[side]['moves']) if agg[side]['moves'] else 0.0

    summary = {
        'games': n_games,
        'engines': {'P0': engine_p0, 'P1': engine_p1},
        'depths':  {'minimax': depth_minimax, 'alphabeta': depth_ab},
        'wins':    {'P0': wins_p0, 'P1': n_games - wins_p0 - ties, 'ties': ties},
        'win_rate_P0': wins_p0 / n_games if n_games else 0.0,
        'avg_nodes_per_move': {'P0': _avg_nodes('P0'), 'P1': _avg_nodes('P1')},
        'avg_time_per_move_s': {'P0': _avg_time('P0'), 'P1': _avg_time('P1')},
        'totals': agg,  # keep raw totals if you want to inspect
    }

    # Pretty print a short report
    print("=== Simulation Summary ===")
    print(f"Games: {summary['games']}")
    print(f"P0 engine: {engine_p0} | P1 engine: {engine_p1}")
    print(f"Depths -> minimax: {depth_minimax}, alphabeta: {depth_ab}")
    print(f"Wins -> P0: {summary['wins']['P0']}, P1: {summary['wins']['P1']}, Ties: {summary['wins']['ties']}")
    print(f"P0 win rate: {summary['win_rate_P0']:.3f}")
    print(f"Avg nodes/move -> P0: {summary['avg_nodes_per_move']['P0']:.1f} | P1: {summary['avg_nodes_per_move']['P1']:.1f}")
    print(f"Avg time/move (s) -> P0: {summary['avg_time_per_move_s']['P0']:.4f} | P1: {summary['avg_time_per_move_s']['P1']:.4f}")

    return summary


# --- Example usage -----------------------------------------------------------
# Quick smoke test with small depths:
summary = simulate_games(
    n_games=10,
    engine_p0="alphabeta_ordered",
    engine_p1="minimax",
    depth_minimax=3,
    depth_ab=3,
    seed=42,
    verbose_every=5
)
# Out:
# [5/10] interim: P0 wins=0, ties=0
# [10/10] interim: P0 wins=0, ties=0
# === Simulation Summary ===
# Games: 10
# P0 engine: alphabeta_ordered | P1 engine: minimax
# Depths -> minimax: 5, alphabeta: 5
# Wins -> P0: 0, P1: 10, Ties: 0
# P0 win rate: 0.000
# Avg nodes/move -> P0: 2074.6 | P1: 27904.2
# Avg time/move (s) -> P0: 0.0753 | P1: 0.3478

# %% [markdown]
# ## 7) (Optional) Iterative Deepening + Time Budget
#
# Implement iterative deepening (depth = 1..D) with a time cutoff; return the best move from the deepest completed search.

# %%
# TODO: iterative deepening scaffold
import time

def choose_move_id(state, max_depth: int = 10, time_limit: float = 1.0):
    """
    Iterative deepening driver over alpha-beta.

    Strategy
    --------
    - Start at depth=1 and repeatedly call `choose_move_alphabeta` with increasing
      depths until either:
        (a) we reach `max_depth`, or
        (b) the wall clock exceeds `time_limit` seconds.
    - Always keep the best move from the *last fully-completed* search depth
      (classic ID pattern), so we can return something even if time expires mid-run.

    Parameters
    ----------
    state : dict
        Current Mancala state (must be compatible with choose_move_alphabeta).
    max_depth : int, default=10
        Maximum search depth (plies) to attempt.
    time_limit : float, default=1.0
        Wall-clock limit in seconds for the entire iterative deepening loop.

    Returns
    -------
    best_mv : int
        The move selected at the deepest completed iteration. Defaults to 0
        if no search iteration could be completed.
    """
    start = time.time()
    best_mv = 0  # fallback in case we can't complete any depth

    for d in range(1, max_depth + 1):
        # Check the time budget *before* starting the next (more expensive) iteration.
        if time.time() - start > time_limit:
            break

        # Run alpha-beta with ordering at the current depth.
        # Note: we ignore stats here; only the move is needed.
        mv, _ = choose_move_alphabeta(state, depth=d, use_ordering=True)

        # If we finished depth d within the time budget, accept this as the current best.
        best_mv = mv

    return best_mv
pass
